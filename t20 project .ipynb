# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.datasets import fetch_california_housing,load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.ensemble import StackingClassifier,StackingRegressor
from sklearn.ensemble import AdaBoostClassifier,AdaBoostRegressor
from sklearn.ensemble import BaggingClassifier,BaggingRegressor
from sklearn.ensemble import VotingClassifier,VotingRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report,mean_squared_error,mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.svm import SVC
import imblearn
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('t20 stats.csv')

# %%
df
# Out:
#                      Player       Span  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0           V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66  1907
# 1         RG Sharma (INDIA)  2007-2019  104    96  14  2633  118  32.10  1905
# 2           MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36  1810
# 3    Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58  1824
# 4          BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66  1571
# ..                      ...        ...  ...   ...  ..   ...  ...    ...   ...
# 537       V Shankar (INDIA)  2018-2019    9     4   0   101   43  25.25    73
# 538        S Dhaniram (CAN)  2008-2010   11     9   0   100   26  11.11   123
# 539       Hamza Tariq (CAN)  2013-2019   15    11   1   100   33  10.00    82
# 540          T Maruma (ZIM)  2008-2019   13    13   4   100  23*  11.11   109
# 541     BS Stephenson (Blz)  2019-2019    3     3   0   100   48  33.33    72
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  542 non-null    object
#  1   Span    542 non-null    object
#  2   Mat     542 non-null    int64
#  3   Inns    542 non-null    int64
#  4   NO      542 non-null    int64
#  5   Runs    542 non-null    int64
#  6   HS      542 non-null    object
#  7   Ave     542 non-null    float64
#  8   BF      542 non-null    int64
#  9   SR      542 non-null    float64
#  10  100     542 non-null    int64
#  11  50      542 non-null    int64
#  12  0       542 non-null    int64
#  13  4s      542 non-null    int64
#  14  6s      542 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 63.6+ KB

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
X=pd.DataFrame(df[['Mat','Inns']])
Y=pd.DataFrame(df['Runs'])

# %%
from sklearn.model_selection import train_test_split

# %%
XTR,XT,YTR,YT=train_test_split(X,Y,train_size=0.8, random_state=1)

# %%
model=LinearRegression()
model.fit(XTR,YTR)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-14.64706775,  37.77635192]])

# %%
model.intercept_
# Out:
# array([-27.18467708])

# %%
#linear regression

# %%
Model=LinearRegression()
Model= Model.fit(XTR,YTR)
Predict=Model.predict(XT)
RMSE = np.sqrt(mean_squared_error(YT,Predict))
MAPE=mean_absolute_percentage_error(YT,Predict)
print(RMSE, MAPE)
# Out:
# 184.34911164836583 0.3657242990982379

# %%
#voting Regressor

# %%
base_model=[('lr',LinearRegression()),('dt',DecisionTreeRegressor()),('rf',RandomForestRegressor())]

# %%
model= VotingRegressor(estimators=base_model)
model.fit(XTR, YTR)
Predict=model.predict(XT)
RMSE = np.sqrt(mean_squared_error(YT,Predict))
MAPE=mean_absolute_percentage_error(YT,Predict)
print(RMSE, MAPE)
# Out:
# 190.4574288908473 0.278447784717085

# %%
#Bagging Regressor

# %%
BModel=BaggingRegressor(estimator=Model, n_estimators=50, random_state=1)
BModel= BModel.fit(XTR,YTR)
Predict=BModel.predict(XT)
RMSE = np.sqrt(mean_squared_error(YT,Predict))
MAPE=mean_absolute_percentage_error(YT,Predict)
print(RMSE, MAPE)
# Out:
# 184.9861734424303 0.3635710399141922

# %%
#Stacking

# %%
base_models =[('DT', DecisionTreeRegressor(random_state=1)),
('RF', RandomForestRegressor(random_state=1)),
('LR', LinearRegression())]

# %%
meta_model = LinearRegression()

# %%
stack_model = StackingRegressor(estimators=base_models, final_estimator=meta_model)

# %%
stack_model
# Out:
# StackingRegressor(estimators=[('DT', DecisionTreeRegressor(random_state=1)),
#                               ('RF', RandomForestRegressor(random_state=1)),
#                               ('LR', LinearRegression())],
#                   final_estimator=LinearRegression())

# %%
Model = stack_model.fit(XTR, YTR)

# %%
Predict=Model.predict(XT)

# %%
np.sqrt(mean_squared_error(YT,Predict))
# Out:
# 183.86826753978664

# %%
mean_absolute_percentage_error(YT,Predict)
# Out:
# 0.32640133786576236

# %%
#Decision Tree

# %%
model= DecisionTreeRegressor()
Model2=model.fit(XTR,YTR)
Predict =Model2.predict(XT)
RMSE = np.sqrt(mean_squared_error(YT,Predict))
MAPE=mean_absolute_percentage_error(YT,Predict)
print(RMSE, MAPE)
# Out:
# 216.90055333092207 0.27782859276764826

# %%
#Final conclusion

# %%
#This project aimed to predict a player's **Total Runs** using two key features: **Matches (Mat)** and **Innings (Inns)**. We evaluated five regression models using **RMSE** (Root Mean Squared Error) and **MAPE** (Mean Absolute Percentage Error).
#The **Decision Tree Regressor** is the best-performing model based on the Mean Absolute Percentage Error (MAPE).
#Lowest Proportional Error: The Decision Tree Regressor achieved the lowest MAPE (**0.281**), indicating that, on average, its prediction error was the smallest proportion of the actual number of runs.
#RMSE Trade-Off: It's important to note that while the Decision Tree had the best MAPE, it also had the **highest RMSE (216.90)**. This suggests the model is volatile: it's often proportionally accurate, but when it is wrong, the absolute error (in terms of actual runs) is significantly larger than the errors made by the Stacking Regressor.
#Recommended Model (Overall):For a stable, production-ready model that minimizes the magnitude of severe errors, the **Stacking Regressor** (RMSE **176.67**) is typically preferred, even though its MAPE is slightly higher.
